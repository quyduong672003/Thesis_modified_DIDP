# %%
import glob
import random
import os
import time
import json
import re
import pandas as pd
import modified_didppy as m_dp
import gc
import traceback # <--- Added for detailed error logs

# --- CONFIGURATION ---
# Path to the folder containing .txt instance files
DATA_FOLDER_PATH = r"C:\Users\ACER\Desktop\Code\0_Thesis_implementation\2_DIDP_custom_search_guidance_local\Thesis_modified_DIDP\5_JSP_dual_bounds_and_models\Datasets\JSPLIB_instances"

# Path to the instances.json file containing BKS
INSTANCES_JSON_PATH = r"C:\Users\ACER\Desktop\Code\0_Thesis_implementation\2_DIDP_custom_search_guidance_local\Thesis_modified_DIDP\5_JSP_dual_bounds_and_models\Datasets\instances.json"

# Output CSV name
OUTPUT_CSV_NAME = "JSP_single_dual_bound_results_10s_lim.csv"

print("Configuration Loaded.")
# Out:
# Configuration Loaded.

# %% [markdown]
# # **Data**

# %%
def parse_jsp_instance(file_content):
    """
    Parses a JSP instance string (Taillard/Beasley/OR-Lib format).
    Format:
    Line 1: num_jobs num_machines
    Lines 2+: machine_index processing_time machine_index processing_time ...
    """
    # 1. Clean and Tokenize
    # Remove comments and split by whitespace
    tokens = []
    for line in file_content.splitlines():
        if not line.strip() or line.strip().startswith(('#', '[')):
            continue
        tokens.extend(re.findall(r'\d+', line))
    
    iterator = iter(tokens)
    
    try:
        num_jobs = int(next(iterator))
        num_machines = int(next(iterator))
    except StopIteration:
        raise ValueError("File is empty or invalid header")

    # 2. Extract Job Data
    # jobs_data format: [ [(machine, time), (machine, time)], ... ]
    jobs_data = []
    for _ in range(num_jobs):
        job_seq = []
        for _ in range(num_machines):
            m = int(next(iterator))
            p = int(next(iterator))
            job_seq.append((m, p))
        jobs_data.append(job_seq)

    num_operations = num_jobs * num_machines

    # 3. Build DIDP Structures (Flattened)
    op_job_type = []
    op_required_machine_type = []
    op_processing_time = []
    op_predecessors = []
    op_deadline = []
    op_same_job = [[] for _ in range(num_operations)] 
    ops_on_machine = [[] for _ in range(num_machines)] 
    map_mj_to_op = {}
    valid_machines = [] # For VM_jo

    # Default deadline (infinity)
    DEFAULT_DEADLINE = float('inf')
    
    op_counter = 0
    for j_idx, job_seq in enumerate(jobs_data):
        job_ops_indices = []
        
        for i, (m, p) in enumerate(job_seq):
            # Attributes
            op_job_type.append(j_idx)
            op_required_machine_type.append(m)
            op_processing_time.append(float(p))
            op_deadline.append(DEFAULT_DEADLINE)
            valid_machines.append([m])
            
            # Map & Sets
            map_mj_to_op[(m, j_idx)] = op_counter
            ops_on_machine[m].append(op_counter)
            job_ops_indices.append(op_counter)
            
            # Predecessors
            if i > 0:
                op_predecessors.append([op_counter - 1])
            else:
                op_predecessors.append([]) 
            
            op_counter += 1
            
        # Same Job Set
        for o_id in job_ops_indices:
            op_same_job[o_id] = [x for x in job_ops_indices if x != o_id]

    # 4. Return Dictionary
    return {
        "metadata": {
            "num_jobs": num_jobs,
            "num_machines": num_machines,
            "num_operations": num_operations
        },
        "DIDP_sets": {
            "op_job_type": op_job_type,
            "op_required_machine_type": op_required_machine_type,
            "op_processing_time": op_processing_time,
            "op_predecessors": op_predecessors,
            "op_deadline": op_deadline,
            "op_same_job": op_same_job,
            "ops_on_machine": ops_on_machine,
            "valid_machines": valid_machines,
            "map_mj_to_op": map_mj_to_op
        }
    }

def load_bks_lookup(json_path):
    """
    Reads the instances.json file and returns a dictionary:
    { 'instance_name': best_known_cost, ... }
    """
    bks_lookup = {}
    
    if not os.path.exists(json_path):
        print(f"Warning: JSON file not found at {json_path}")
        return bks_lookup

    try:
        with open(json_path, 'r') as f:
            data = json.load(f)
            
        # Iterate through the list of instances in the JSON
        for entry in data:
            name = entry.get('name')
            optimum = entry.get('optimum')
            
            # Fallback logic from load_instance.py
            if optimum is None:
                bounds = entry.get('bounds')
                if bounds:
                    optimum = bounds.get('lower') # Or 'upper' if you prefer UB as BKS
            
            # Handle string 'nan' or None
            if optimum == "nan" or optimum is None:
                optimum = None
            else:
                optimum = float(optimum)
                
            if name:
                bks_lookup[name] = optimum
                
        print(f"Loaded BKS for {len(bks_lookup)} instances.")
        
    except Exception as e:
        print(f"Error reading JSON: {e}")
        
    return bks_lookup

# %%
# Initialize Global Variables (MUST exist for model function)
current_number_of_operations = 0
current_number_of_machines = 0
current_number_of_jobs = 0
current_op_job_type = []
current_op_required_machine_type = []
current_op_processing_time = []
current_op_deadline = []
current_op_predecessors = []
current_op_same_job = []
current_ops_on_machine = []
current_valid_machines = []
current_map_mj_to_op = {}

# %% [markdown]
# # **DIDP model**

# %%
def creation_of_didp_model_function():
    # -----------------------------
    # 1. Retrieve Global Variables
    # -----------------------------
    num_operations = current_number_of_operations
    num_machines = current_number_of_machines
    op_processing_time = current_op_processing_time
    op_deadline = current_op_deadline
    op_predecessors = current_op_predecessors
    op_same_job = current_op_same_job
    valid_machines = current_valid_machines
    ops_on_machine = current_ops_on_machine
    
    # NEW: Added requested variables
    op_job_type = current_op_job_type
    op_required_machine_type = current_op_required_machine_type

    # -----------------------------
    # 2. DIDP Model and Constants
    # -----------------------------
    model = m_dp.Model(maximize=False, float_cost=True)

    operation_obj = model.add_object_type(number=num_operations)
    machine_obj = model.add_object_type(number=num_machines)

    # Constant tables
    processing_time_table = model.add_float_table(op_processing_time)
    deadline_table = model.add_float_table(op_deadline)
    predecessor_table = model.add_set_table(op_predecessors, object_type=operation_obj)
    same_job_table = model.add_set_table(op_same_job, object_type=operation_obj)
    valid_machine_table = model.add_set_table(valid_machines, object_type=operation_obj)

    # -----------------------------
    # 3. State Variables
    # -----------------------------
    unscheduled_operations = model.add_set_var(object_type=operation_obj,
                                    target=list(range(num_operations)))
    finished_operations = model.add_set_var(object_type=operation_obj, target=[])
    machine_available_time = [
        model.add_float_resource_var(target=0, less_is_better=True, name=f"at_{mi}")
        for mi in range(num_machines)
    ]
    op_completion_time = [
        model.add_float_resource_var(target=0, less_is_better=True, name=f"c_{jo}")
        for jo in range(num_operations)
    ]

    # ------------------------------------------------------------
    # 4. Transitions
    # ------------------------------------------------------------
    # Schedule operation jo on the specified machine
    # ------------------------------------------------------------
    for o in range(num_operations):
        valid_machines_for_op = valid_machines[o]
        expr = m_dp.FloatExpr(0)
        #Finding the completion time of the predecessors to make sure 1 job cannot be operated on 2 machines at the same time
        if op_same_job[o]:
            job_exprs = [op_completion_time[k] for k in op_same_job[o]]
            expr = job_exprs[0]
            for e in job_exprs[1:]:
                expr = m_dp.max(expr, e)
        max_same_job_completion_time = expr
        for m in valid_machines_for_op:
            # Compute start & completion
            start_time = m_dp.max(machine_available_time[m], max_same_job_completion_time)
            completion_time = start_time + processing_time_table[o]
            cost_expr = m_dp.FloatExpr.state_cost()
            transition = m_dp.Transition(
                name=f"schedule_op{o}_on_m{m}",
                cost=cost_expr,
                preconditions=[
                    unscheduled_operations.contains(o),
                    predecessor_table[o].issubset(finished_operations),
                    completion_time <= deadline_table[o],
                ],
                effects=[
                    (unscheduled_operations, unscheduled_operations.remove(o)),
                    (finished_operations, finished_operations.add(o)),
                    (op_completion_time[o], completion_time),
                    (machine_available_time[m], completion_time),
                ],
            )
            model.add_transition(transition)

    # ------------------------------------------------------------
    # 5. Base case (OPTIMIZED)
    # ------------------------------------------------------------
    
    # Helper function to build a balanced max tree
    def build_balanced_max(expr_list):
        if not expr_list:
            return m_dp.FloatExpr(0)
        if len(expr_list) == 1:
            return expr_list[0]
        
        # Split in half
        mid = len(expr_list) // 2
        left_expr = build_balanced_max(expr_list[:mid])
        right_expr = build_balanced_max(expr_list[mid:])
        
        return m_dp.max(left_expr, right_expr)

    # Collect all completion time expressions into a list
    all_completion_times = [op_completion_time[o] for o in range(num_operations)]
    
    # Build the balanced expression
    makespan = build_balanced_max(all_completion_times)
    
    model.add_base_case([unscheduled_operations.is_empty()], cost=makespan)

    # ------------------------------------------------------------
    # Back up Base case
    # ------------------------------------------------------------
    """makespan = m_dp.FloatExpr(0)
    for o in range(num_operations):
        makespan = m_dp.max(makespan, op_completion_time[o])
    model.add_base_case([unscheduled_operations.is_empty()], cost=makespan)"""
    
    # ------------------------------------------------------------
    # 6. State Constraints
    # ------------------------------------------------------------
    # Enforce 0 <= completion time <= deadline for all operations
    for o in range(num_operations):
        # Upper bound: c(o) <= d(o)
        model.add_state_constr(op_completion_time[o] <= deadline_table[o])

        # ------------------------------------------------------------
    # 7. Dual Bound (optional)
    # ------------------------------------------------------------
    # Machine-based bound: for each machine m, available_time[m] + sum(remaining ptime on that machine)
    ops_on_machine_consts = [
        model.create_set_const(object_type=operation_obj, value=ops) for ops in ops_on_machine
    ]
    # remaining processing time on machine m = sum of ptime for operations on m that are still unscheduled
    remaining_time_on_machine = [
        processing_time_table[unscheduled_operations.intersection(ops_on_machine_consts[m])]
        for m in range(num_machines)
    ]
    machine_bound_exprs = [
        machine_available_time[m] + remaining_time_on_machine[m]
        for m in range(num_machines)
    ]

    # fold to a single dp.max expression
    dual_bound_expr = machine_bound_exprs[0]
    for b in machine_bound_exprs[1:]:
        dual_bound_expr = m_dp.max(dual_bound_expr, b)

    # Add dual bound to model
    model.add_dual_bound(dual_bound_expr)
    #"""

    # =========================================================
    # 8. Bundle Metadata
    # =========================================================
    metadata = {
        "unscheduled_operations": unscheduled_operations,
        "finished_operations": finished_operations,
        "machine_available_time": machine_available_time,
        "op_completion_time": op_completion_time,
        # Added the requested new variables to metadata
        "op_job_type": op_job_type,
        "op_required_machine_type": op_required_machine_type
    }
    
    didp_bundle = (model, metadata)
    return didp_bundle

# %% [markdown]
# # **Execution**

# %%
bks_map = load_bks_lookup(INSTANCES_JSON_PATH)
all_files = glob.glob(os.path.join(DATA_FOLDER_PATH, "*.txt"))

# Select 10 random files
num_instances_to_test = 1000
if len(all_files) > num_instances_to_test:
    selected_files = random.sample(all_files, num_instances_to_test)
else:
    selected_files = all_files

print(f"Found {len(all_files)} files. Selected {len(selected_files)} for testing.")
for file in selected_files:
    print(f"Selected file is: {os.path.basename(file)}")
results_data = []
# Out:
# Loaded BKS for 162 instances.
# Found 162 files. Selected 162 for testing.
# Selected file is: abz5.txt
# Selected file is: abz6.txt
# Selected file is: abz7.txt
# Selected file is: abz8.txt
# Selected file is: abz9.txt
# Selected file is: ft06.txt
# Selected file is: ft10.txt
# Selected file is: ft20.txt
# Selected file is: la01.txt
# Selected file is: la02.txt
# Selected file is: la03.txt
# Selected file is: la04.txt
# Selected file is: la05.txt
# Selected file is: la06.txt
# Selected file is: la07.txt
# Selected file is: la08.txt
# Selected file is: la09.txt
# Selected file is: la10.txt
# Selected file is: la11.txt
# Selected file is: la12.txt
# Selected file is: la13.txt
# Selected file is: la14.txt
# Selected file is: la15.txt
# Selected file is: la16.txt
# Selected file is: la17.txt
# Selected file is: la18.txt
# Selected file is: la19.txt
# Selected file is: la20.txt
# Selected file is: la21.txt
# Selected file is: la22.txt
# Selected file is: la23.txt
# Selected file is: la24.txt
# Selected file is: la25.txt
# Selected file is: la26.txt
# Selected file is: la27.txt
# Selected file is: la28.txt
# Selected file is: la29.txt
# Selected file is: la30.txt
# Selected file is: la31.txt
# Selected file is: la32.txt
# Selected file is: la33.txt
# Selected file is: la34.txt
# Selected file is: la35.txt
# Selected file is: la36.txt
# Selected file is: la37.txt
# Selected file is: la38.txt
# Selected file is: la39.txt
# Selected file is: la40.txt
# Selected file is: orb01.txt
# Selected file is: orb02.txt
# Selected file is: orb03.txt
# Selected file is: orb04.txt
# Selected file is: orb05.txt
# Selected file is: orb06.txt
# Selected file is: orb07.txt
# Selected file is: orb08.txt
# Selected file is: orb09.txt
# Selected file is: orb10.txt
# Selected file is: swv01.txt
# Selected file is: swv02.txt
# Selected file is: swv03.txt
# Selected file is: swv04.txt
# Selected file is: swv05.txt
# Selected file is: swv06.txt
# Selected file is: swv07.txt
# Selected file is: swv08.txt
# Selected file is: swv09.txt
# Selected file is: swv10.txt
# Selected file is: swv11.txt
# Selected file is: swv12.txt
# Selected file is: swv13.txt
# Selected file is: swv14.txt
# Selected file is: swv15.txt
# Selected file is: swv16.txt
# Selected file is: swv17.txt
# Selected file is: swv18.txt
# Selected file is: swv19.txt
# Selected file is: swv20.txt
# Selected file is: ta01.txt
# Selected file is: ta02.txt
# Selected file is: ta03.txt
# Selected file is: ta04.txt
# Selected file is: ta05.txt
# Selected file is: ta06.txt
# Selected file is: ta07.txt
# Selected file is: ta08.txt
# Selected file is: ta09.txt
# Selected file is: ta10.txt
# Selected file is: ta11.txt
# Selected file is: ta12.txt
# Selected file is: ta13.txt
# Selected file is: ta14.txt
# Selected file is: ta15.txt
# Selected file is: ta16.txt
# Selected file is: ta17.txt
# Selected file is: ta18.txt
# Selected file is: ta19.txt
# Selected file is: ta20.txt
# Selected file is: ta21.txt
# Selected file is: ta22.txt
# Selected file is: ta23.txt
# Selected file is: ta24.txt
# Selected file is: ta25.txt
# Selected file is: ta26.txt
# Selected file is: ta27.txt
# Selected file is: ta28.txt
# Selected file is: ta29.txt
# Selected file is: ta30.txt
# Selected file is: ta31.txt
# Selected file is: ta32.txt
# Selected file is: ta33.txt
# Selected file is: ta34.txt
# Selected file is: ta35.txt
# Selected file is: ta36.txt
# Selected file is: ta37.txt
# Selected file is: ta38.txt
# Selected file is: ta39.txt
# Selected file is: ta40.txt
# Selected file is: ta41.txt
# Selected file is: ta42.txt
# Selected file is: ta43.txt
# Selected file is: ta44.txt
# Selected file is: ta45.txt
# Selected file is: ta46.txt
# Selected file is: ta47.txt
# Selected file is: ta48.txt
# Selected file is: ta49.txt
# Selected file is: ta50.txt
# Selected file is: ta51.txt
# Selected file is: ta52.txt
# Selected file is: ta53.txt
# Selected file is: ta54.txt
# Selected file is: ta55.txt
# Selected file is: ta56.txt
# Selected file is: ta57.txt
# Selected file is: ta58.txt
# Selected file is: ta59.txt
# Selected file is: ta60.txt
# Selected file is: ta61.txt
# Selected file is: ta62.txt
# Selected file is: ta63.txt
# Selected file is: ta64.txt
# Selected file is: ta65.txt
# Selected file is: ta66.txt
# Selected file is: ta67.txt
# Selected file is: ta68.txt
# Selected file is: ta69.txt
# Selected file is: ta70.txt
# Selected file is: ta71.txt
# Selected file is: ta72.txt
# Selected file is: ta73.txt
# Selected file is: ta74.txt
# Selected file is: ta75.txt
# Selected file is: ta76.txt
# Selected file is: ta77.txt
# Selected file is: ta78.txt
# Selected file is: ta79.txt
# Selected file is: ta80.txt
# Selected file is: yn1.txt
# Selected file is: yn2.txt
# Selected file is: yn3.txt
# Selected file is: yn4.txt

# %%
# ==========================================
# EXECUTION LOOP
# ==========================================

# Load BKS
bks_map = load_bks_lookup(INSTANCES_JSON_PATH)

# Get ALL Files and Sort them
all_files = sorted(glob.glob(os.path.join(DATA_FOLDER_PATH, "*.txt")))
selected_files = all_files 

print(f"Found {len(all_files)} files. Processing ALL of them.")
print("-" * 50)

results_data = []

# Init Globals
current_number_of_operations = 0
current_number_of_machines = 0
current_number_of_jobs = 0
current_op_job_type = []
current_op_required_machine_type = []
current_op_processing_time = []
current_op_deadline = []
current_op_predecessors = []
current_op_same_job = []
current_ops_on_machine = []
current_valid_machines = []
current_map_mj_to_op = {}

for i, file_path in enumerate(selected_files):
    filename = os.path.basename(file_path)
    instance_name = os.path.splitext(filename)[0]
    
    print(f"\n[{i+1}/{len(selected_files)}] Processing: {instance_name}")
    
    best_known_cost = bks_map.get(instance_name, None)
    
    # Init vars for cleanup
    model = None
    solver = None
    solution = None
    parsed_data = None
    
    try:
        # -------------------------------------------------
        # A. Read & Parse (Outer Try Block)
        # -------------------------------------------------
        with open(file_path, 'r') as f: content = f.read()
        parsed_data = parse_jsp_instance(content)
        
        num_ops = parsed_data['metadata']['num_operations']
        meta = parsed_data['metadata']
        
        # -------------------------------------------------
        # B. Update Globals
        # -------------------------------------------------
        didp_sets = parsed_data['DIDP_sets']
        current_number_of_operations = num_ops
        current_number_of_machines = meta['num_machines']
        current_number_of_jobs = meta['num_jobs']
        current_op_job_type = didp_sets['op_job_type']
        current_op_required_machine_type = didp_sets['op_required_machine_type']
        current_op_processing_time = didp_sets['op_processing_time']
        current_op_deadline = didp_sets['op_deadline']
        current_op_predecessors = didp_sets['op_predecessors']
        current_op_same_job = didp_sets['op_same_job']
        current_ops_on_machine = didp_sets['ops_on_machine']
        current_valid_machines = didp_sets['valid_machines']
        current_map_mj_to_op = didp_sets['map_mj_to_op']
        
        print(f"   -> Info: {meta['num_jobs']} jobs, {meta['num_machines']} machines ({num_ops} ops)")
        
        # -------------------------------------------------
        # C. CRITICAL SAFETY CHECK
        # -------------------------------------------------
        if num_ops > 500:
            print(f"   -> SKIP: {num_ops} operations > 300 (Stack Limit).")
            results_data.append({
                "Instance": instance_name, "Best Known Cost": best_known_cost,
                "Cost": "Skipped", "Gap to BKC": "N/A",
                "Nodes Expanded": 0, "Nodes Generated": 0, "Running Time (s)": 0, 
                "Is Optimal": "False (Size Limit)", "Is Optimal": "Error", "Infeasibility": "Error"
            })
            # We use 'continue' here, but we must ensure Save/Cleanup happens.
            # So we jump to the 'finally' logic by breaking the flow or saving immediately.
            # Simplest way: Save here and continue loop
            pd.DataFrame(results_data).to_csv(OUTPUT_CSV_NAME, index=False)
            continue 

        # -------------------------------------------------
        # D. Model & Solve (Inner Try Block for Detail)
        # -------------------------------------------------
        try:
            # Creation
            try:
                didp_bundle = creation_of_didp_model_function()
                model, _ = didp_bundle 
            except Exception as e:
                print(f"   -> ❌ CREATION ERROR: {e}")
                results_data.append({
                "Instance": instance_name, "Best Known Cost": best_known_cost,
                "Cost": "Error (model creation)", "Gap to BKC": "N/A",
                "Nodes Expanded": 0, "Nodes Generated": 0, "Running Time (s)": 0, 
                "Is Optimal": "Error", "Infeasibility": "Error"
                })
                continue

            # Solving
            t_start = time.time()
            solver = m_dp.CABS(model, quiet=True, time_limit=10) 
            solution = solver.search()
            duration = time.time() - t_start
            
            # Processing
            if solution.is_optimal:
                cost = solution.cost
                status = "True"
            elif solution.cost is not None:
                cost = solution.cost
                status = "False (Time Limit)"
            else:
                cost = float('inf')
                status = "False (No Sol)"

            # Gap
            gap = "N/A"
            if best_known_cost is not None and cost != float('inf'):
                try:
                    gap_val = ((cost - best_known_cost) / best_known_cost) * 100
                    gap = f"{gap_val:.2f}%"
                except: gap = "Error"

            print(f"   -> Result: Cost {cost} | BKC {best_known_cost} | Gap {gap}")

            results_data.append({
                "Instance": instance_name,
                "Best Known Cost": best_known_cost,
                "Cost": cost,
                "Gap to BKC": gap,
                "Nodes Expanded": solution.expanded,
                "Nodes Generated": solution.generated,
                "Running Time (s)": duration,
                "Is Optimal": status,
                "Infeasibility": solution.is_infeasible
            })

        except Exception as e:
            # THIS CATCHES MODEL/SOLVER ERRORS SPECIFICALLY
            print(f"   -> ❌ SOLVER ERROR: {e}")
            print("   -> Detail Traceback:")
            traceback.print_exc() # <--- PRINTS FULL ERROR DETAILS
            
            results_data.append({
                "Instance": instance_name, "Best Known Cost": best_known_cost,
                "Cost": "Error (Model)", "Gap to BKC": "N/A",
                "Nodes Expanded": 0, "Nodes Generated": 0, "Running Time (s)": 0, 
                "Is Optimal": "Error", "Infeasibility": "Error"
            })

    except Exception as e:
        # THIS CATCHES PARSING/FILE ERRORS
        print(f"   -> ❌ GENERAL ERROR: {e}")
        results_data.append({
            "Instance": instance_name, "Best Known Cost": best_known_cost,
            "Cost": "Error (General)", "Gap to BKC": "N/A",
            "Nodes Expanded": 0, "Nodes Generated": 0, "Running Time (s)": 0, 
            "Is Optimal": "Error", "Infeasibility": "Error"
        })

    # ==========================================
    # SAVE & CLEANUP (Always runs)
    # ==========================================
    # 1. Save CSV
    pd.DataFrame(results_data).to_csv(OUTPUT_CSV_NAME, index=False)

    # 2. Memory Cleanup
    try:
        del model
        del solver
        del solution
        del parsed_data
    except: pass
    gc.collect()

print("\n" + "="*50)
print(f"Batch Testing Complete. Saved to {OUTPUT_CSV_NAME}")
# Out:
# Loaded BKS for 162 instances.
# Found 162 files. Processing ALL of them.
# --------------------------------------------------
#
# [1/162] Processing: abz5
#    -> Info: 10 jobs, 10 machines (100 ops)
#    -> Result: Cost 1401.0 | BKC 1234.0 | Gap 13.53%
#
# [2/162] Processing: abz6
#    -> Info: 10 jobs, 10 machines (100 ops)
#    -> Result: Cost 1049.0 | BKC 943.0 | Gap 11.24%
#
# [3/162] Processing: abz7
#    -> Info: 20 jobs, 15 machines (300 ops)
#    -> Result: Cost 949.0 | BKC 656.0 | Gap 44.66%
#
# [4/162] Processing: abz8
#    -> Info: 20 jobs, 15 machines (300 ops)
#    -> Result: Cost 962.0 | BKC 645.0 | Gap 49.15%
#
# [5/162] Processing: abz9
#    -> Info: 20 jobs, 15 machines (300 ops)
#    -> Result: Cost 945.0 | BKC 661.0 | Gap 42.97%
#
# [6/162] Processing: ft06
#    -> Info: 6 jobs, 6 machines (36 ops)
#    -> Result: Cost 55.0 | BKC 55.0 | Gap 0.00%
#
# [7/162] Processing: ft10
#    -> Info: 10 jobs, 10 machines (100 ops)
#    -> Result: Cost 1165.0 | BKC 930.0 | Gap 25.27%
#
# [8/162] Processing: ft20
#    -> Info: 20 jobs, 5 machines (100 ops)
#    -> Result: Cost 1533.0 | BKC 1165.0 | Gap 31.59%
#
# [9/162] Processing: la01
#    -> Info: 10 jobs, 5 machines (50 ops)
#    -> Result: Cost 718.0 | BKC 666.0 | Gap 7.81%
#
# [10/162] Processing: la02
#    -> Info: 10 jobs, 5 machines (50 ops)
#    -> Result: Cost 744.0 | BKC 655.0 | Gap 13.59%
#
# [11/162] Processing: la03
#    -> Info: 10 jobs, 5 machines (50 ops)
#    -> Result: Cost 651.0 | BKC 597.0 | Gap 9.05%
#
# [12/162] Processing: la04
#    -> Info: 10 jobs, 5 machines (50 ops)
#    -> Result: Cost 646.0 | BKC 590.0 | Gap 9.49%
#
# [13/162] Processing: la05
#    -> Info: 10 jobs, 5 machines (50 ops)
#    -> Result: Cost 593.0 | BKC 593.0 | Gap 0.00%
#
# [14/162] Processing: la06
#    -> Info: 15 jobs, 5 machines (75 ops)
#    -> Result: Cost 967.0 | BKC 926.0 | Gap 4.43%
#
# [15/162] Processing: la07
#    -> Info: 15 jobs, 5 machines (75 ops)
#    -> Result: Cost 978.0 | BKC 890.0 | Gap 9.89%
#
# [16/162] Processing: la08
#    -> Info: 15 jobs, 5 machines (75 ops)
#    -> Result: Cost 1000.0 | BKC 863.0 | Gap 15.87%
#
# [17/162] Processing: la09
#    -> Info: 15 jobs, 5 machines (75 ops)
#    -> Result: Cost 968.0 | BKC 951.0 | Gap 1.79%
#
# [18/162] Processing: la10
#    -> Info: 15 jobs, 5 machines (75 ops)
#    -> Result: Cost 1002.0 | BKC 958.0 | Gap 4.59%
#
# [19/162] Processing: la11
#    -> Info: 20 jobs, 5 machines (100 ops)
#    -> Result: Cost 1370.0 | BKC 1222.0 | Gap 12.11%
#
# [20/162] Processing: la12
#    -> Info: 20 jobs, 5 machines (100 ops)
#    -> Result: Cost 1165.0 | BKC 1039.0 | Gap 12.13%
#
# [21/162] Processing: la13
#    -> Info: 20 jobs, 5 machines (100 ops)
#    -> Result: Cost 1233.0 | BKC 1150.0 | Gap 7.22%
#
# [22/162] Processing: la14
#    -> Info: 20 jobs, 5 machines (100 ops)
#    -> Result: Cost 1354.0 | BKC 1292.0 | Gap 4.80%
#
# [23/162] Processing: la15
#    -> Info: 20 jobs, 5 machines (100 ops)
#    -> Result: Cost 1422.0 | BKC 1207.0 | Gap 17.81%
#
# [24/162] Processing: la16
#    -> Info: 10 jobs, 10 machines (100 ops)
#    -> Result: Cost 1109.0 | BKC 945.0 | Gap 17.35%
#
# [25/162] Processing: la17
#    -> Info: 10 jobs, 10 machines (100 ops)
#    -> Result: Cost 925.0 | BKC 784.0 | Gap 17.98%
#
# [26/162] Processing: la18
#    -> Info: 10 jobs, 10 machines (100 ops)
#    -> Result: Cost 948.0 | BKC 848.0 | Gap 11.79%
#
# [27/162] Processing: la19
#    -> Info: 10 jobs, 10 machines (100 ops)
#    -> Result: Cost 1036.0 | BKC 842.0 | Gap 23.04%
#
# [28/162] Processing: la20
#    -> Info: 10 jobs, 10 machines (100 ops)
#    -> Result: Cost 1087.0 | BKC 902.0 | Gap 20.51%
#
# [29/162] Processing: la21
#    -> Info: 15 jobs, 10 machines (150 ops)
#    -> Result: Cost 1347.0 | BKC 1046.0 | Gap 28.78%
#
# [30/162] Processing: la22
#    -> Info: 15 jobs, 10 machines (150 ops)
#    -> Result: Cost 1326.0 | BKC 927.0 | Gap 43.04%
#
# [31/162] Processing: la23
#    -> Info: 15 jobs, 10 machines (150 ops)
#    -> Result: Cost 1427.0 | BKC 1032.0 | Gap 38.28%
#
# [32/162] Processing: la24
#    -> Info: 15 jobs, 10 machines (150 ops)
#    -> Result: Cost 1293.0 | BKC 935.0 | Gap 38.29%
#
# [33/162] Processing: la25
#    -> Info: 15 jobs, 10 machines (150 ops)
#    -> Result: Cost 1194.0 | BKC 977.0 | Gap 22.21%
#
# [34/162] Processing: la26
#    -> Info: 20 jobs, 10 machines (200 ops)
#    -> Result: Cost 1624.0 | BKC 1218.0 | Gap 33.33%
#
# [35/162] Processing: la27
#    -> Info: 20 jobs, 10 machines (200 ops)
#    -> Result: Cost 1584.0 | BKC 1235.0 | Gap 28.26%
#
# [36/162] Processing: la28
#    -> Info: 20 jobs, 10 machines (200 ops)
#    -> Result: Cost 1646.0 | BKC 1216.0 | Gap 35.36%
#
# [37/162] Processing: la29
#    -> Info: 20 jobs, 10 machines (200 ops)
#    -> Result: Cost 1728.0 | BKC 1152.0 | Gap 50.00%
#
# [38/162] Processing: la30
#    -> Info: 20 jobs, 10 machines (200 ops)
#    -> Result: Cost 1859.0 | BKC 1355.0 | Gap 37.20%
#
# [39/162] Processing: la31
#    -> Info: 30 jobs, 10 machines (300 ops)
#    -> Result: Cost 2597.0 | BKC 1784.0 | Gap 45.57%
#
# [40/162] Processing: la32
#    -> Info: 30 jobs, 10 machines (300 ops)
#    -> Result: Cost 2385.0 | BKC 1850.0 | Gap 28.92%
#
# [41/162] Processing: la33
#    -> Info: 30 jobs, 10 machines (300 ops)
#    -> Result: Cost 2241.0 | BKC 1719.0 | Gap 30.37%
#
# [42/162] Processing: la34
#    -> Info: 30 jobs, 10 machines (300 ops)
#    -> Result: Cost 2251.0 | BKC 1721.0 | Gap 30.80%
#
# [43/162] Processing: la35
#    -> Info: 30 jobs, 10 machines (300 ops)
#    -> Result: Cost 2732.0 | BKC 1888.0 | Gap 44.70%
#
# [44/162] Processing: la36
#    -> Info: 15 jobs, 15 machines (225 ops)
#    -> Result: Cost 1727.0 | BKC 1268.0 | Gap 36.20%
#
# [45/162] Processing: la37
#    -> Info: 15 jobs, 15 machines (225 ops)
#    -> Result: Cost 1855.0 | BKC 1397.0 | Gap 32.78%
#
# [46/162] Processing: la38
#    -> Info: 15 jobs, 15 machines (225 ops)
#    -> Result: Cost 1650.0 | BKC 1196.0 | Gap 37.96%
#
# [47/162] Processing: la39
#    -> Info: 15 jobs, 15 machines (225 ops)
#    -> Result: Cost 1734.0 | BKC 1233.0 | Gap 40.63%
#
# [48/162] Processing: la40
#    -> Info: 15 jobs, 15 machines (225 ops)
#    -> Result: Cost 1740.0 | BKC 1222.0 | Gap 42.39%
#
# [49/162] Processing: orb01
#    -> Info: 10 jobs, 10 machines (100 ops)
#    -> Result: Cost 1339.0 | BKC 1059.0 | Gap 26.44%
#
# [50/162] Processing: orb02
#    -> Info: 10 jobs, 10 machines (100 ops)
#    -> Result: Cost 1093.0 | BKC 888.0 | Gap 23.09%
#
# [51/162] Processing: orb03
#    -> Info: 10 jobs, 10 machines (100 ops)
#    -> Result: Cost 1291.0 | BKC 1005.0 | Gap 28.46%
#
# [52/162] Processing: orb04
#    -> Info: 10 jobs, 10 machines (100 ops)
#    -> Result: Cost 1248.0 | BKC 1005.0 | Gap 24.18%
#
# [53/162] Processing: orb05
#    -> Info: 10 jobs, 10 machines (100 ops)
#    -> Result: Cost 1034.0 | BKC 887.0 | Gap 16.57%
#
# [54/162] Processing: orb06
#    -> Info: 10 jobs, 10 machines (100 ops)
#    -> Result: Cost 1321.0 | BKC 1010.0 | Gap 30.79%
#
# [55/162] Processing: orb07
#    -> Info: 10 jobs, 10 machines (100 ops)
#    -> Result: Cost 486.0 | BKC 397.0 | Gap 22.42%
#
# [56/162] Processing: orb08
#    -> Info: 10 jobs, 10 machines (100 ops)
#    -> Result: Cost 1223.0 | BKC 899.0 | Gap 36.04%
#
# [57/162] Processing: orb09
#    -> Info: 10 jobs, 10 machines (100 ops)
#    -> Result: Cost 1089.0 | BKC 934.0 | Gap 16.60%
#
# [58/162] Processing: orb10
#    -> Info: 10 jobs, 10 machines (100 ops)
#    -> Result: Cost 1109.0 | BKC 944.0 | Gap 17.48%
#
# [59/162] Processing: swv01
#    -> Info: 20 jobs, 10 machines (200 ops)
#    -> Result: Cost 2058.0 | BKC 1407.0 | Gap 46.27%
#
# [60/162] Processing: swv02
#    -> Info: 20 jobs, 10 machines (200 ops)
#    -> Result: Cost 2094.0 | BKC 1475.0 | Gap 41.97%
#
# [61/162] Processing: swv03
#    -> Info: 20 jobs, 10 machines (200 ops)
#    -> Result: Cost 1902.0 | BKC 1369.0 | Gap 38.93%
#
# [62/162] Processing: swv04
#    -> Info: 20 jobs, 10 machines (200 ops)
#    -> Result: Cost 2111.0 | BKC 1450.0 | Gap 45.59%
#
# [63/162] Processing: swv05
#    -> Info: 20 jobs, 10 machines (200 ops)
#    -> Result: Cost 2033.0 | BKC 1424.0 | Gap 42.77%
#
# [64/162] Processing: swv06
#    -> Info: 20 jobs, 15 machines (300 ops)
#    -> Result: Cost 2673.0 | BKC 1591.0 | Gap 68.01%
#
# [65/162] Processing: swv07
#    -> Info: 20 jobs, 15 machines (300 ops)
#    -> Result: Cost 2395.0 | BKC 1446.0 | Gap 65.63%
#
# [66/162] Processing: swv08
#    -> Info: 20 jobs, 15 machines (300 ops)
#    -> Result: Cost 2844.0 | BKC 1640.0 | Gap 73.41%
#
# [67/162] Processing: swv09
#    -> Info: 20 jobs, 15 machines (300 ops)
#    -> Result: Cost 2720.0 | BKC 1604.0 | Gap 69.58%
#
# [68/162] Processing: swv10
#    -> Info: 20 jobs, 15 machines (300 ops)
#    -> Result: Cost 2498.0 | BKC 1631.0 | Gap 53.16%
#
# [69/162] Processing: swv11
#    -> Info: 50 jobs, 10 machines (500 ops)
#    -> Result: Cost 4189.0 | BKC 2983.0 | Gap 40.43%
#
# [70/162] Processing: swv12
#    -> Info: 50 jobs, 10 machines (500 ops)
#    -> Result: Cost 4598.0 | BKC 2972.0 | Gap 54.71%
#
# [71/162] Processing: swv13
#    -> Info: 50 jobs, 10 machines (500 ops)
#    -> Result: Cost 4999.0 | BKC 3104.0 | Gap 61.05%
#
# [72/162] Processing: swv14
#    -> Info: 50 jobs, 10 machines (500 ops)
#    -> Result: Cost 4275.0 | BKC 2968.0 | Gap 44.04%
#
# [73/162] Processing: swv15
#    -> Info: 50 jobs, 10 machines (500 ops)
#    -> Result: Cost 4194.0 | BKC 2885.0 | Gap 45.37%
#
# [74/162] Processing: swv16
#    -> Info: 50 jobs, 10 machines (500 ops)
#    -> Result: Cost 3499.0 | BKC 2924.0 | Gap 19.66%
#
# [75/162] Processing: swv17
#    -> Info: 50 jobs, 10 machines (500 ops)
#    -> Result: Cost 3521.0 | BKC 2794.0 | Gap 26.02%
#
# [76/162] Processing: swv18
#    -> Info: 50 jobs, 10 machines (500 ops)
#    -> Result: Cost 3401.0 | BKC 2852.0 | Gap 19.25%
#
# [77/162] Processing: swv19
#    -> Info: 50 jobs, 10 machines (500 ops)
#    -> Result: Cost 3478.0 | BKC 2843.0 | Gap 22.34%
#
# [78/162] Processing: swv20
#    -> Info: 50 jobs, 10 machines (500 ops)
#    -> Result: Cost 3478.0 | BKC 2823.0 | Gap 23.20%
#
# [79/162] Processing: ta01
#    -> Info: 15 jobs, 15 machines (225 ops)
#    -> Result: Cost 1947.0 | BKC 1231.0 | Gap 58.16%
#
# [80/162] Processing: ta02
#    -> Info: 15 jobs, 15 machines (225 ops)
#    -> Result: Cost 1752.0 | BKC 1244.0 | Gap 40.84%
#
# [81/162] Processing: ta03
#    -> Info: 15 jobs, 15 machines (225 ops)
#    -> Result: Cost 1651.0 | BKC 1218.0 | Gap 35.55%
#
# [82/162] Processing: ta04
#    -> Info: 15 jobs, 15 machines (225 ops)
#    -> Result: Cost 1633.0 | BKC 1175.0 | Gap 38.98%
#
# [83/162] Processing: ta05
#    -> Info: 15 jobs, 15 machines (225 ops)
#    -> Result: Cost 1687.0 | BKC 1224.0 | Gap 37.83%
#
# [84/162] Processing: ta06
#    -> Info: 15 jobs, 15 machines (225 ops)
#    -> Result: Cost 1741.0 | BKC 1238.0 | Gap 40.63%
#
# [85/162] Processing: ta07
#    -> Info: 15 jobs, 15 machines (225 ops)
#    -> Result: Cost 1868.0 | BKC 1227.0 | Gap 52.24%
#
# [86/162] Processing: ta08
#    -> Info: 15 jobs, 15 machines (225 ops)
#    -> Result: Cost 1730.0 | BKC 1217.0 | Gap 42.15%
#
# [87/162] Processing: ta09
#    -> Info: 15 jobs, 15 machines (225 ops)
#    -> Result: Cost 1853.0 | BKC 1274.0 | Gap 45.45%
#
# [88/162] Processing: ta10
#    -> Info: 15 jobs, 15 machines (225 ops)
#    -> Result: Cost 1650.0 | BKC 1241.0 | Gap 32.96%
#
# [89/162] Processing: ta11
#    -> Info: 20 jobs, 15 machines (300 ops)
#    -> Result: Cost 2093.0 | BKC 1323.0 | Gap 58.20%
#
# [90/162] Processing: ta12
#    -> Info: 20 jobs, 15 machines (300 ops)
#    -> Result: Cost 2084.0 | BKC 1351.0 | Gap 54.26%
#
# [91/162] Processing: ta13
#    -> Info: 20 jobs, 15 machines (300 ops)
#    -> Result: Cost 2010.0 | BKC 1282.0 | Gap 56.79%
#
# [92/162] Processing: ta14
#    -> Info: 20 jobs, 15 machines (300 ops)
#    -> Result: Cost 1872.0 | BKC 1345.0 | Gap 39.18%
#
# [93/162] Processing: ta15
#    -> Info: 20 jobs, 15 machines (300 ops)
#    -> Result: Cost 2118.0 | BKC 1304.0 | Gap 62.42%
#
# [94/162] Processing: ta16
#    -> Info: 20 jobs, 15 machines (300 ops)
#    -> Result: Cost 1961.0 | BKC 1302.0 | Gap 50.61%
#
# [95/162] Processing: ta17
#    -> Info: 20 jobs, 15 machines (300 ops)
#    -> Result: Cost 2219.0 | BKC 1462.0 | Gap 51.78%
#
# [96/162] Processing: ta18
#    -> Info: 20 jobs, 15 machines (300 ops)
#    -> Result: Cost 1999.0 | BKC 1369.0 | Gap 46.02%
#
# [97/162] Processing: ta19
#    -> Info: 20 jobs, 15 machines (300 ops)
#    -> Result: Cost 2112.0 | BKC 1297.0 | Gap 62.84%
#
# [98/162] Processing: ta20
#    -> Info: 20 jobs, 15 machines (300 ops)
#    -> Result: Cost 2084.0 | BKC 1318.0 | Gap 58.12%
#
# [99/162] Processing: ta21
#    -> Info: 20 jobs, 20 machines (400 ops)
#    -> Result: Cost 2315.0 | BKC 1539.0 | Gap 50.42%
#
# [100/162] Processing: ta22
#    -> Info: 20 jobs, 20 machines (400 ops)
#    -> Result: Cost 2660.0 | BKC 1511.0 | Gap 76.04%
#
# [101/162] Processing: ta23
#    -> Info: 20 jobs, 20 machines (400 ops)
#    -> Result: Cost 2362.0 | BKC 1472.0 | Gap 60.46%
#
# [102/162] Processing: ta24
#    -> Info: 20 jobs, 20 machines (400 ops)
#    -> Result: Cost 2593.0 | BKC 1602.0 | Gap 61.86%
#
# [103/162] Processing: ta25
#    -> Info: 20 jobs, 20 machines (400 ops)
#    -> Result: Cost 2491.0 | BKC 1504.0 | Gap 65.62%
#
# [104/162] Processing: ta26
#    -> Info: 20 jobs, 20 machines (400 ops)
#    -> Result: Cost 2431.0 | BKC 1539.0 | Gap 57.96%
#
# [105/162] Processing: ta27
#    -> Info: 20 jobs, 20 machines (400 ops)
#    -> Result: Cost 2541.0 | BKC 1616.0 | Gap 57.24%
#
# [106/162] Processing: ta28
#    -> Info: 20 jobs, 20 machines (400 ops)
#    -> Result: Cost 2528.0 | BKC 1591.0 | Gap 58.89%
#
# [107/162] Processing: ta29
#    -> Info: 20 jobs, 20 machines (400 ops)
#    -> Result: Cost 2592.0 | BKC 1514.0 | Gap 71.20%
#
# [108/162] Processing: ta30
#    -> Info: 20 jobs, 20 machines (400 ops)
#    -> Result: Cost 2303.0 | BKC 1473.0 | Gap 56.35%
#
# [109/162] Processing: ta31
#    -> Info: 30 jobs, 15 machines (450 ops)
#    -> Result: Cost 2777.0 | BKC 1764.0 | Gap 57.43%
#
# [110/162] Processing: ta32
#    -> Info: 30 jobs, 15 machines (450 ops)
#    -> Result: Cost 2842.0 | BKC 1774.0 | Gap 60.20%
#
# [111/162] Processing: ta33
#    -> Info: 30 jobs, 15 machines (450 ops)
#    -> Result: Cost 2617.0 | BKC 1778.0 | Gap 47.19%
#
# [112/162] Processing: ta34
#    -> Info: 30 jobs, 15 machines (450 ops)
#    -> Result: Cost 2916.0 | BKC 1828.0 | Gap 59.52%
#
# [113/162] Processing: ta35
#    -> Info: 30 jobs, 15 machines (450 ops)
#    -> Result: Cost 2880.0 | BKC 2007.0 | Gap 43.50%
#
# [114/162] Processing: ta36
#    -> Info: 30 jobs, 15 machines (450 ops)
#    -> Result: Cost 2832.0 | BKC 1819.0 | Gap 55.69%
#
# [115/162] Processing: ta37
#    -> Info: 30 jobs, 15 machines (450 ops)
#    -> Result: Cost 2685.0 | BKC 1771.0 | Gap 51.61%
#
# [116/162] Processing: ta38
#    -> Info: 30 jobs, 15 machines (450 ops)
#    -> Result: Cost 2614.0 | BKC 1673.0 | Gap 56.25%
#
# [117/162] Processing: ta39
#    -> Info: 30 jobs, 15 machines (450 ops)
#    -> Result: Cost 2512.0 | BKC 1795.0 | Gap 39.94%
#
# [118/162] Processing: ta40
#    -> Info: 30 jobs, 15 machines (450 ops)
#    -> Result: Cost 2556.0 | BKC 1631.0 | Gap 56.71%
#
# [119/162] Processing: ta41
#    -> Info: 30 jobs, 20 machines (600 ops)
#    -> SKIP: 600 operations > 300 (Stack Limit).
#
# [120/162] Processing: ta42
#    -> Info: 30 jobs, 20 machines (600 ops)
#    -> SKIP: 600 operations > 300 (Stack Limit).
#
# [121/162] Processing: ta43
#    -> Info: 30 jobs, 20 machines (600 ops)
#    -> SKIP: 600 operations > 300 (Stack Limit).
#
# [122/162] Processing: ta44
#    -> Info: 30 jobs, 20 machines (600 ops)
#    -> SKIP: 600 operations > 300 (Stack Limit).
#
# [123/162] Processing: ta45
#    -> Info: 30 jobs, 20 machines (600 ops)
#    -> SKIP: 600 operations > 300 (Stack Limit).
#
# [124/162] Processing: ta46
#    -> Info: 30 jobs, 20 machines (600 ops)
#    -> SKIP: 600 operations > 300 (Stack Limit).
#
# [125/162] Processing: ta47
#    -> Info: 30 jobs, 20 machines (600 ops)
#    -> SKIP: 600 operations > 300 (Stack Limit).
#
# [126/162] Processing: ta48
#    -> Info: 30 jobs, 20 machines (600 ops)
#    -> SKIP: 600 operations > 300 (Stack Limit).
#
# [127/162] Processing: ta49
#    -> Info: 30 jobs, 20 machines (600 ops)
#    -> SKIP: 600 operations > 300 (Stack Limit).
#
# [128/162] Processing: ta50
#    -> Info: 30 jobs, 20 machines (600 ops)
#    -> SKIP: 600 operations > 300 (Stack Limit).
#
# [129/162] Processing: ta51
#    -> Info: 50 jobs, 15 machines (750 ops)
#    -> SKIP: 750 operations > 300 (Stack Limit).
#
# [130/162] Processing: ta52
#    -> Info: 50 jobs, 15 machines (750 ops)
#    -> SKIP: 750 operations > 300 (Stack Limit).
#
# [131/162] Processing: ta53
#    -> Info: 50 jobs, 15 machines (750 ops)
#    -> SKIP: 750 operations > 300 (Stack Limit).
#
# [132/162] Processing: ta54
#    -> Info: 50 jobs, 15 machines (750 ops)
#    -> SKIP: 750 operations > 300 (Stack Limit).
#
# [133/162] Processing: ta55
#    -> Info: 50 jobs, 15 machines (750 ops)
#    -> SKIP: 750 operations > 300 (Stack Limit).
#
# [134/162] Processing: ta56
#    -> Info: 50 jobs, 15 machines (750 ops)
#    -> SKIP: 750 operations > 300 (Stack Limit).
#
# [135/162] Processing: ta57
#    -> Info: 50 jobs, 15 machines (750 ops)
#    -> SKIP: 750 operations > 300 (Stack Limit).
#
# [136/162] Processing: ta58
#    -> Info: 50 jobs, 15 machines (750 ops)
#    -> SKIP: 750 operations > 300 (Stack Limit).
#
# [137/162] Processing: ta59
#    -> Info: 50 jobs, 15 machines (750 ops)
#    -> SKIP: 750 operations > 300 (Stack Limit).
#
# [138/162] Processing: ta60
#    -> Info: 50 jobs, 15 machines (750 ops)
#    -> SKIP: 750 operations > 300 (Stack Limit).
#
# [139/162] Processing: ta61
#    -> Info: 50 jobs, 20 machines (1000 ops)
#    -> SKIP: 1000 operations > 300 (Stack Limit).
#
# [140/162] Processing: ta62
#    -> Info: 50 jobs, 20 machines (1000 ops)
#    -> SKIP: 1000 operations > 300 (Stack Limit).
#
# [141/162] Processing: ta63
#    -> Info: 50 jobs, 20 machines (1000 ops)
#    -> SKIP: 1000 operations > 300 (Stack Limit).
#
# [142/162] Processing: ta64
#    -> Info: 50 jobs, 20 machines (1000 ops)
#    -> SKIP: 1000 operations > 300 (Stack Limit).
#
# [143/162] Processing: ta65
#    -> Info: 50 jobs, 20 machines (1000 ops)
#    -> SKIP: 1000 operations > 300 (Stack Limit).
#
# [144/162] Processing: ta66
#    -> Info: 50 jobs, 20 machines (1000 ops)
#    -> SKIP: 1000 operations > 300 (Stack Limit).
#
# [145/162] Processing: ta67
#    -> Info: 50 jobs, 20 machines (1000 ops)
#    -> SKIP: 1000 operations > 300 (Stack Limit).
#
# [146/162] Processing: ta68
#    -> Info: 50 jobs, 20 machines (1000 ops)
#    -> SKIP: 1000 operations > 300 (Stack Limit).
#
# [147/162] Processing: ta69
#    -> Info: 50 jobs, 20 machines (1000 ops)
#    -> SKIP: 1000 operations > 300 (Stack Limit).
#
# [148/162] Processing: ta70
#    -> Info: 50 jobs, 20 machines (1000 ops)
#    -> SKIP: 1000 operations > 300 (Stack Limit).
#
# [149/162] Processing: ta71
#    -> Info: 100 jobs, 20 machines (2000 ops)
#    -> SKIP: 2000 operations > 300 (Stack Limit).
#
# [150/162] Processing: ta72
#    -> Info: 100 jobs, 20 machines (2000 ops)
#    -> SKIP: 2000 operations > 300 (Stack Limit).
#
# [151/162] Processing: ta73
#    -> Info: 100 jobs, 20 machines (2000 ops)
#    -> SKIP: 2000 operations > 300 (Stack Limit).
#
# [152/162] Processing: ta74
#    -> Info: 100 jobs, 20 machines (2000 ops)
#    -> SKIP: 2000 operations > 300 (Stack Limit).
#
# [153/162] Processing: ta75
#    -> Info: 100 jobs, 20 machines (2000 ops)
#    -> SKIP: 2000 operations > 300 (Stack Limit).
#
# [154/162] Processing: ta76
#    -> Info: 100 jobs, 20 machines (2000 ops)
#    -> SKIP: 2000 operations > 300 (Stack Limit).
#
# [155/162] Processing: ta77
#    -> Info: 100 jobs, 20 machines (2000 ops)
#    -> SKIP: 2000 operations > 300 (Stack Limit).
#
# [156/162] Processing: ta78
#    -> Info: 100 jobs, 20 machines (2000 ops)
#    -> SKIP: 2000 operations > 300 (Stack Limit).
#
# [157/162] Processing: ta79
#    -> Info: 100 jobs, 20 machines (2000 ops)
#    -> SKIP: 2000 operations > 300 (Stack Limit).
#
# [158/162] Processing: ta80
#    -> Info: 100 jobs, 20 machines (2000 ops)
#    -> SKIP: 2000 operations > 300 (Stack Limit).
#
# [159/162] Processing: yn1
#    -> Info: 20 jobs, 20 machines (400 ops)
#    -> Result: Cost 1270.0 | BKC 826.0 | Gap 53.75%
#
# [160/162] Processing: yn2
#    -> Info: 20 jobs, 20 machines (400 ops)
#    -> Result: Cost 1446.0 | BKC 861.0 | Gap 67.94%
#
# [161/162] Processing: yn3
#    -> Info: 20 jobs, 20 machines (400 ops)
#    -> Result: Cost 1299.0 | BKC 827.0 | Gap 57.07%
#
# [162/162] Processing: yn4
#    -> Info: 20 jobs, 20 machines (400 ops)
#    -> Result: Cost 1404.0 | BKC 918.0 | Gap 52.94%
#
# ==================================================
# Batch Testing Complete. Saved to JSP_single_dual_bound_results_10s_lim.csv

# %% [markdown]
# # **Running with a single file**

# %%
lone_selected_files =['C:\\Users\\ACER\\Desktop\\Code\\0_Thesis_implementation\\2_DIDP_custom_search_guidance_local\\Thesis_modified_DIDP\\5_JSP_dual_bounds_and_models\\Datasets\\JSPLIB_instances\\ft06.txt']
for i, file_path in enumerate(lone_selected_files):
    filename = os.path.basename(file_path)
    instance_name = os.path.splitext(filename)[0]
    print(f"\n[{i+1}/{len(lone_selected_files)}] Processing: {instance_name}")
    best_known_cost = bks_map.get(instance_name, None)
    # Init vars for cleanup
    model = None
    solver = None
    solution = None
    parsed_data = None
    
    with open(file_path, 'r') as f: content = f.read()
    parsed_data = parse_jsp_instance(content)
    num_ops = parsed_data['metadata']['num_operations']
    meta = parsed_data['metadata']
    # -------------------------------------------------
    # B. Update Globals
    # -------------------------------------------------
    didp_sets = parsed_data['DIDP_sets']
    current_number_of_operations = num_ops
    current_number_of_machines = meta['num_machines']
    current_number_of_jobs = meta['num_jobs']
    current_op_job_type = didp_sets['op_job_type']
    current_op_required_machine_type = didp_sets['op_required_machine_type']
    current_op_processing_time = didp_sets['op_processing_time']
    current_op_deadline = didp_sets['op_deadline']
    current_op_predecessors = didp_sets['op_predecessors']
    current_op_same_job = didp_sets['op_same_job']
    current_ops_on_machine = didp_sets['ops_on_machine']
    current_valid_machines = didp_sets['valid_machines']
    current_map_mj_to_op = didp_sets['map_mj_to_op']

    print(f"   -> Info: {meta['num_jobs']} jobs, {meta['num_machines']} machines ({num_ops} ops)")

    # -------------------------------------------------
    # D. Model & Solve (Inner Try Block for Detail)
    # -------------------------------------------------

    didp_bundle = creation_of_didp_model_function()
    model, _ = didp_bundle 

    # Solving
    t_start = time.time()
    solver = m_dp.CABS(model, quiet=True, time_limit=10) 
    solution = solver.search()
    duration = time.time() - t_start

    # Processing
    print(f"Solution Cost: {solution.cost}")
    print(f"Running Time: {duration} seconds")
    print("Transitions in the solution:")
    for t in solution.transitions:
        print(t.name)
# Out:
# [1/1] Processing: ft06
#    -> Info: 6 jobs, 6 machines (36 ops)
# Solution Cost: 55.0
# Running Time: 10.006349325180054 seconds
# Transitions in the solution:
# schedule_op0_on_m2
# schedule_op12_on_m2
# schedule_op6_on_m1
# schedule_op30_on_m1
# schedule_op13_on_m3
# schedule_op7_on_m2
# schedule_op24_on_m2
# schedule_op18_on_m1
# schedule_op25_on_m1
# schedule_op31_on_m3
# schedule_op1_on_m0
# schedule_op2_on_m1
# schedule_op19_on_m0
# schedule_op14_on_m5
# schedule_op32_on_m5
# schedule_op8_on_m4
# schedule_op15_on_m0
# schedule_op9_on_m5
# schedule_op26_on_m4
# schedule_op33_on_m0
# schedule_op10_on_m0
# schedule_op20_on_m2
# schedule_op16_on_m1
# schedule_op21_on_m3
# schedule_op22_on_m4
# schedule_op17_on_m4
# schedule_op34_on_m4
# schedule_op35_on_m2
# schedule_op3_on_m3
# schedule_op27_on_m5
# schedule_op4_on_m5
# schedule_op5_on_m4
# schedule_op28_on_m0
# schedule_op11_on_m3
# schedule_op23_on_m5
# schedule_op29_on_m3

# %% [markdown]
# # **Selected instances**

# %%
# ==========================================
# USER SETTINGS
# ==========================================

# 1. Define your data folder path (Update this if needed)
# DATA_FOLDER_PATH = r"C:\Users\ACER\Desktop\Code\...\Datasets\JSPLIB_instances"

# 2. LIST FOR YOU TO SPECIFY THE NAMES
# Add the filenames you want to run here.
# If you leave this list EMPTY [], the code will scan the folder and run ALL .txt files.
manual_instances_to_run = [
    "abz5.txt",
    "ft06.txt",
    "ft10.txt",
    "la07.txt",
    "la21.txt",
    
    "la26.txt",
    "ta01.txt",
    "ft20.txt",
    "ta20.txt",
    "ta41.txt"
]

# ==========================================
# GENERATION LOGIC
# ==========================================

instance_names = []

if len(manual_instances_to_run) > 0:
    print(f"Using manual selection of {len(manual_instances_to_run)} instances.")
    instance_names = manual_instances_to_run
else:
    print("Manual list is empty. Scanning folder for all .txt files...")
    if 'DATA_FOLDER_PATH' not in locals():
        print("Error: DATA_FOLDER_PATH is not defined. Please define it or fill the manual list.")
        all_files = []
    else:
        all_files = glob.glob(os.path.join(DATA_FOLDER_PATH, "*.txt"))
        instance_names = [os.path.basename(f) for f in all_files]
        print(f"Found {len(instance_names)} instances in folder.")

# Save to CSV for the next step
df_instances = pd.DataFrame(instance_names, columns=["Instance"])
input_csv_name = "JSP_target_instances.csv" 

df_instances.to_csv(input_csv_name, index=False)

print(f"\nSaved list to: {input_csv_name}")
print(df_instances)
# Out:
# Using manual selection of 10 instances.
#
# Saved list to: JSP_target_instances.csv
#    Instance
# 0  abz5.txt
# 1  ft06.txt
# 2  ft10.txt
# 3  la07.txt
# 4  la21.txt
# 5  la26.txt
# 6  ta01.txt
# 7  ft20.txt
# 8  ta20.txt
# 9  ta41.txt

# %% [markdown]
# # **Run single dual bound model on selected instances**

# %%
import time as pytime
# ==========================================
# CONFIGURATION
# ==========================================
input_csv_path = "JSP_target_instances.csv"   # Reads the list you created in Step 1
output_csv_name = "JSP_single_dual_bound_selected_results_1800s_lim.csv"
time_limit_seconds = 1800

# Ensure bks_map is loaded. If 'load_bks_lookup' is not defined in your notebook,
# you can define a simple dictionary here manually or ensure the previous cells are run.
import csv

bks_map = {}

# Path to your CSV file
csv_file = "JSP_single_dual_bound_selected_results_10s_lim.csv"

with open(csv_file, newline="") as f:
    reader = csv.DictReader(f)
    for row in reader:
        # Remove ".txt" from instance name
        instance_name = row["Instance"].replace(".txt", "")
        # Convert Best Known Cost to integer
        best_known_cost = float(row["Best Known Cost"])
        bks_map[instance_name] = best_known_cost

print(bks_map)

# ==========================================
# RESUME LOGIC
# ==========================================
processed_instances = []

if os.path.exists(output_csv_name):
    try:
        df_existing = pd.read_csv(output_csv_name)
        if "Instance" in df_existing.columns:
            processed_instances = df_existing["Instance"].tolist()
        print(f"Found existing results. Resuming... ({len(processed_instances)} instances already done).")
    except:
        pass

# Read the target list
try:
    df_target = pd.read_csv(input_csv_path)
    all_target_instances = df_target["Instance"].tolist()
except Exception as e:
    print(f"Error reading {input_csv_path}: {e}")
    all_target_instances = []

remaining_instances = [inst for inst in all_target_instances if inst not in processed_instances]
print(f"Queued {len(remaining_instances)} instances for execution.")
# Out:
# {'abz5': 1234.0, 'ft06': 55.0, 'ft10': 930.0, 'la07': 890.0, 'la21': 1046.0, 'la26': 1218.0, 'ta01': 1231.0, 'ft20': 1165.0, 'ta20': 1318.0, 'ta41': 1859.0}
# Queued 10 instances for execution.

# %%
# ==========================================
# EXECUTION LOOP
# ==========================================
for i, instance_name in enumerate(remaining_instances):
    print(f"\n[{i+1}/{len(remaining_instances)}] Processing: {instance_name}")
    
    file_path = os.path.join(DATA_FOLDER_PATH, instance_name)
    
    # Get BKS
    short_name = os.path.splitext(instance_name)[0]
    best_known_cost = bks_map.get(short_name, None) if 'bks_map' in locals() else None
    
    result_entry = {
        "Instance": instance_name,
        "Best Known Cost": best_known_cost,
        "Cost": float('inf'),
        "Gap to BKC": "N/A",
        "Nodes Expanded": 0,
        "Nodes Generated": 0,
        "Running Time (s)": 0,
        "Is Optimal": "Error",
        "Infeasibility": "Error"
    }
    
    try:
        # 1. Parse Data
        with open(file_path, 'r') as f:
            content = f.read()
        parsed_data = parse_jsp_instance(content) # Assumes this function exists from your notebook

        # 2. Update Global Variables
        didp_sets = parsed_data['DIDP_sets']
        current_number_of_operations = parsed_data['metadata']['num_operations']
        current_number_of_machines = parsed_data['metadata']['num_machines']
        current_number_of_jobs = parsed_data['metadata']['num_jobs']
        
        current_op_job_type = didp_sets['op_job_type']
        current_op_required_machine_type = didp_sets['op_required_machine_type']
        current_op_processing_time = didp_sets['op_processing_time']
        current_op_deadline = didp_sets['op_deadline']
        current_op_predecessors = didp_sets['op_predecessors']
        current_op_same_job = didp_sets['op_same_job']
        current_ops_on_machine = didp_sets['ops_on_machine']
        current_valid_machines = didp_sets['valid_machines']
        current_map_mj_to_op = didp_sets['map_mj_to_op']

        # 3. Create Model
        didp_bundle = creation_of_didp_model_function() # Assumes this function exists
        model, _ = didp_bundle

        # 4. Solve
        t_start = pytime.time()
        solver = m_dp.CABS(model, quiet=True, time_limit=time_limit_seconds)
        solution = solver.search()
        duration = pytime.time() - t_start

        # 5. Process Results
        if solution.is_optimal:
            cost = solution.cost
            status = "True"
        elif solution.cost is not None:
            cost = solution.cost
            status = "False (Time Limit)"
        else:
            cost = float('inf')
            status = "False (No Sol)"
            
        gap = "N/A"
        if best_known_cost is not None and cost != float('inf'):
            try:
                gap_val = ((cost - best_known_cost) / best_known_cost) * 100
                gap = f"{gap_val:.2f}%"
            except: gap = "Error"

        print(f"   -> Cost: {cost} | BKC: {best_known_cost} | Gap: {gap}")
        print(f"   -> Time: {duration:.2f}s | Status: {status}")

        result_entry.update({
            "Cost": cost,
            "Gap to BKC": gap,
            "Nodes Expanded": solution.expanded,
            "Nodes Generated": solution.generated,
            "Running Time (s)": duration,
            "Is Optimal": status,
            "Infeasibility": solution.is_infeasible
        })

    except Exception as e:
        print(f"   -> ERROR: {e}")
        result_entry["Infeasibility"] = str(e)

    # 6. Save Immediately
    df_res = pd.DataFrame([result_entry])
    df_res.to_csv(output_csv_name, mode='a', header=not os.path.exists(output_csv_name), index=False)
    
    gc.collect()

print("\n" + "="*50)
print(f"Execution complete. Results saved to {output_csv_name}")
# Out:
# [1/10] Processing: abz5.txt
#    -> Cost: 1288.0 | BKC: 1234.0 | Gap: 4.38%
#    -> Time: 1800.12s | Status: False (Time Limit)
#
# [2/10] Processing: ft06.txt
#    -> Cost: 55.0 | BKC: 55.0 | Gap: 0.00%
#    -> Time: 331.00s | Status: True
#
# [3/10] Processing: ft10.txt
#    -> Cost: 1045.0 | BKC: 930.0 | Gap: 12.37%
#    -> Time: 1800.16s | Status: False (Time Limit)
#
# [4/10] Processing: la07.txt
#    -> Cost: 890.0 | BKC: 890.0 | Gap: 0.00%
#    -> Time: 1800.24s | Status: False (Time Limit)
#
# [5/10] Processing: la21.txt
#    -> Cost: 1290.0 | BKC: 1046.0 | Gap: 23.33%
#    -> Time: 1800.07s | Status: False (Time Limit)
#
# [6/10] Processing: la26.txt
#    -> Cost: 1529.0 | BKC: 1218.0 | Gap: 25.53%
#    -> Time: 1800.07s | Status: False (Time Limit)
#
# [7/10] Processing: ta01.txt
#    -> Cost: 1656.0 | BKC: 1231.0 | Gap: 34.52%
#    -> Time: 1800.10s | Status: False (Time Limit)
#
# [8/10] Processing: ft20.txt
#    -> Cost: 1461.0 | BKC: 1165.0 | Gap: 25.41%
#    -> Time: 1800.04s | Status: False (Time Limit)
#
# [9/10] Processing: ta20.txt
#    -> Cost: 1745.0 | BKC: 1318.0 | Gap: 32.40%
#    -> Time: 1800.08s | Status: False (Time Limit)
#
# [10/10] Processing: ta41.txt
#    -> Cost: 3048.0 | BKC: 1859.0 | Gap: 63.96%
#    -> Time: 1800.18s | Status: False (Time Limit)
#
# ==================================================
# Execution complete. Results saved to JSP_single_dual_bound_selected_results_1800s_lim.csv
